# %%
# !pip install transformers datasets torch pandas scikit-learn openpyxl accelerate -U

import pandas as pd
import re
import numpy as np
from sklearn.model_selection import train_test_split
from datasets import Dataset, DatasetDict
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import torch

# Load the Excel file from the local directory
file_path = r"C:\Users\Michael\Downloads\BERTmodel\final_comments.xlsx"
data = pd.read_excel(file_path)

# Print the column names to verify
print("Columns in the dataset:", data.columns)

# Use the correct column names based on the inspection
correct_comment_column = 'careprovidercomments'
wait_score_column = 'Updated_Wait'
bert_wait_column = 'BERT_Wait'

# Work with the first 1000 rows
data = data.iloc[:1000]

# Drop rows with NaN values in the wait score column
data = data.dropna(subset=[wait_score_column])

# Print unique values in the wait score column after dropping NaNs
print("Unique values in the wait score column after dropping NaNs:", data[wait_score_column].unique())

# Function to clean punctuation
def clean_text(text):
    if isinstance(text, str):
        # Remove all punctuation except periods
        text = re.sub(r'[^\w\s.]', '', text)
    else:
        text = ''
    return text

# Clean the comments
data['cleaned_comment'] = data[correct_comment_column].apply(clean_text)

# Ensure wait scores are 0 and 1
def ensure_wait_scores(data, column):
    if not data[column].between(0, 1).all():
        raise ValueError("Wait scores must be 0 or 1.")

ensure_wait_scores(data, wait_score_column)


# Split the data into training and testing sets (80/20 split)
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42,stratify = data[wait_score_column])

# Print the sizes of the training and testing sets
print(f"Training set size: {len(train_data)} comments")
print(f"Test set size: {len(test_data)} comments")

# Free up memory by deleting the original dataframe
del data

# Convert the data to Hugging Face datasets
train_dataset = Dataset.from_pandas(train_data)
test_dataset = Dataset.from_pandas(test_data)
dataset_dict = DatasetDict({"train": train_dataset, "test": test_dataset})

# Free up memory by deleting the Pandas dataframes
del train_data, test_data

# Initialize tokenizer with smaller max_length
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def tokenize_function(examples):
    return tokenizer(examples['cleaned_comment'], padding='max_length', truncation=True, max_length=64)

tokenized_datasets = dataset_dict.map(tokenize_function, batched=True)

def format_labels(examples):
    examples["labels"] = [int(label) for label in examples[wait_score_column]]
    return examples

tokenized_datasets = tokenized_datasets.map(format_labels, batched=True)

# Free up memory by deleting the original datasets
del dataset_dict

# Print tokenized dataset sizes for debugging
print(f"Tokenized training set size: {len(tokenized_datasets['train'])} comments")
print(f"Tokenized test set size: {len(tokenized_datasets['test'])} comments")

# Load the model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Training arguments with reduced batch sizes
training_args = TrainingArguments(
    output_dir=r"C:\Users\Michael\Downloads\BERT_MODEL_TRAINING_RESULTS-20240701T162037Z-002",  # Update with your local path
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.01,
    fp16=True,
    logging_strategy="steps",
    logging_steps=50,
)

# Define evaluation metrics
def compute_metrics(p):
    preds = np.argmax(p.predictions, axis=1)
    precision, recall, f1, _ = precision_recall_fscore_support(p.label_ids, preds, average='macro')
    acc = accuracy_score(p.label_ids, preds)
    return {"accuracy": acc, "f1": f1, "precision": precision, "recall": recall}

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    compute_metrics=compute_metrics,
)

# Print expected number of steps per epoch
expected_steps_per_epoch = len(tokenized_datasets['train']) // training_args.per_device_train_batch_size
print(f"Expected number of steps per epoch: {expected_steps_per_epoch}")

# Train the model
trainer.train()

# Unified predict function
def predict(texts, model, tokenizer, batch_size=4):
    model.eval()
    if not isinstance(texts, list):
        texts = texts.tolist()

    predictions = []
    probabilities = []

    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        encoded_inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors='pt')

        with torch.no_grad():
            outputs = model(**encoded_inputs)

        logits = outputs.logits
        batch_probabilities = torch.nn.functional.softmax(logits, dim=-1)
        batch_predictions = torch.argmax(batch_probabilities, dim=-1)

        predictions.extend(batch_predictions.cpu().numpy())
        probabilities.extend(batch_probabilities.cpu().numpy())

    return np.array(predictions), np.array(probabilities)

def evaluate_model(test_dataset, model, tokenizer):
    texts = test_dataset['cleaned_comment']
    true_labels = test_dataset[wait_score_column].tolist()

    predictions, probabilities = predict(texts, model, tokenizer)

    precision, recall, f1, _ = precision_recall_fscore_support(true_labels, predictions, average='macro')
    accuracy = accuracy_score(true_labels, predictions)

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

    return predictions, probabilities

# Convert the test dataset to a pandas DataFrame
test_data = tokenized_datasets['test'].to_pandas()

# Evaluate the model
predictions, probabilities = evaluate_model(test_data, model, tokenizer)

# Inspect the predictions and their probabilities

for i in range(len(test_data)):
    print(f"Text: {test_data['cleaned_comment'].iloc[i]}")
    print(f"True Label: {test_data[wait_score_column].iloc[i]}")
    print(f"Predicted Label: {predictions[i]}")
    print(f"Probabilities: {probabilities[i]}")
    print()

# Re-load the full dataset including comments without wait scores
full_data = pd.read_excel(file_path)

# Clean the comments
full_data['cleaned_comment'] = full_data[correct_comment_column].apply(clean_text)

# Get predictions
comments_to_predict = full_data['cleaned_comment'].tolist()
predicted_labels, predicted_probabilities = predict(comments_to_predict, model, tokenizer)

# Add predicted labels to the data in the BERT_Wait column
full_data[bert_wait_column] = predicted_labels

# List of columns to keep
columns_to_keep =['ID', 'unidentifiableid', 'Combined_Sentiment', 'Combined_Wait',
       'Updated_Wait',
       'BERT_Sentiment', 'BERT_Wait', 'BERT_MistakeMedical',
       'careprovidercomments',
       'Medical_Mistakes', 'Clerical_Mistakes', 'Communication_Mistakes']
# Drop columns not in the list
full_data = full_data[columns_to_keep]

# Save the full data with predictions back to the original Excel file
full_data.to_excel(file_path, index=False)  # Overwrite the original file
# Out:
# Requirement already satisfied: transformers in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (4.44.2)
# Requirement already satisfied: datasets in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (3.0.0)
# Requirement already satisfied: torch in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (2.4.1)
# Requirement already satisfied: pandas in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: openpyxl in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: accelerate in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (0.34.2)
# Requirement already satisfied: filelock in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.5.0)
# Requirement already satisfied: aiohttp in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: et-xmlfile in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: psutil in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: six>=1.5 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch) (1.3.0)
# Columns in the dataset: Index(['ID', 'unidentifiableid', 'Combined_Sentiment', 'Combined_Wait',
#        'Updated_Wait', 'BERT_Sentiment', 'BERT_Wait', 'BERT_MistakeMedical',
#        'BERT_MistakeClerical', 'careprovidercomments', 'Medical_Mistakes',
#        'Clerical_Mistakes', 'Communication_Mistakes'],
#       dtype='object')
# Unique values in the wait score column after dropping NaNs: [0. 1.]
# Training set size: 800 comments
# Test set size: 200 comments
# C:\Users\Michael\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Tokenized training set size: 800 comments
# Tokenized test set size: 200 comments
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Expected number of steps per epoch: 400
#     <div>
#
#       <progress value='1200' max='1200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1200/1200 19:41, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.177500</td>
#       <td>0.177967</td>
#       <td>0.970000</td>
#       <td>0.492386</td>
#       <td>0.485000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.078300</td>
#       <td>0.153615</td>
#       <td>0.975000</td>
#       <td>0.715828</td>
#       <td>0.823181</td>
#       <td>0.664089</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000200</td>
#       <td>0.167124</td>
#       <td>0.980000</td>
#       <td>0.744898</td>
#       <td>0.989899</td>
#       <td>0.666667</td>
#     </tr>
#   </tbody>
# </table><p>
# C:\Users\Michael\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9800
# Precision: 0.9899
# Recall: 0.6667
# F1 Score: 0.7449
# Text: Dr. Mirci was great.  He put me at ease and was very pleasant.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99899626e-01 1.00309524e-04]
#
# Text: I have complete confidence in all of the Doctors who have and are treating me at the Medical Center.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989057e-01 1.0948102e-04]
#
# Text: All really good.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989641e-01 1.0352623e-04]
#
# Text: This visit he seemed a little rushed. Unlike all other visits.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9987125e-01 1.2867477e-04]
#
# Text: Thank you for advising a quick response... Sounds important that we move aggressively.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9987483e-01 1.2513080e-04]
#
# Text: Great
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.998870e-01 1.129444e-04]
#
# Text: I have already highly recommended Dr Ambati to my friends and family.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988675e-01 1.1318331e-04]
#
# Text: I felt really rushed at the end. I wanted to ask him some questions about acne and he told me next time that he didnt have time during this appointment. I even asked the nurse if I could talk to him about the acne. That was a frusteration that I would have had to drive clear back there for another appointment just to ask him for some medication for my acne. And I wont...
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9976200e-01 2.3805891e-04]
#
# Text: Dr Henrie was efficient and pleasant to deal with and put us at ease.  He was also forthcoming about his training and education to deal with an additional problem that I brought up and handled it with expertise.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989700e-01 1.0303883e-04]
#
# Text: I wish the care provider would recommend me to where to go for my mama gram and set it up for me.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99878883e-01 1.21159224e-04]
#
# Text: Both the doctor and his attending staff were very attentive to my questions.  He offered excellent advice and let me know I could count on him anytime in the future.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99889016e-01 1.10962326e-04]
#
# Text: GREAT CARE
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989319e-01 1.0682632e-04]
#
# Text: I consider Dr. Bowen to be the very best.  It isnt necessary to my satisfection but I like him very much too.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989343e-01 1.0653476e-04]
#
# Text: Dr. Nimer is fantastic. grateful hes my doc
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.999000e-01 9.998254e-05]
#
# Text: Dr. Steffens is awesome.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99897361e-01 1.02638915e-04]
#
# Text: I cant say enough good things about Dr. Tristani.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988997e-01 1.0996313e-04]
#
# Text: We have been patients of Dr CangaSiao in her prior practice. I am so glad we can continue with her. No one has ever controlled Barbaras blood sugar like she has. We are grateful for her knowledge and do recommend her whenever we can.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9986827e-01 1.3169393e-04]
#
# Text: Dr. Gelner was awesome and friendly and gave me good information.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989724e-01 1.0280730e-04]
#
# Text: We have had 2 appts. with Dr. Young and she has spent more time with us than any other doctor ever has including our primary care pediatrician whom we really like.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99880433e-01 1.19519456e-04]
#
# Text: we saw a pediatric fellow who did our echo he was great. we then saw the doctor who only spent about 2 minutes with us. he was very brief and although the information he provided was sufficient it would have been nice had he spent at least a few minutes with us rather than the rushed feeling that because we didnt have any issues we werent worth his time.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [0.99823284 0.00176718]
#
# Text: Dr. Sussman struck me first as an attractive woman unexpected in a doctor then I discovered that she was charming and straightforward with her approach to me and appeared very competent and caring. It was a totally unexpected and very satisfying experience.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988174e-01 1.1819015e-04]
#
# Text: Dr explained medical reseans later after my visit didnt know about other meds til I was home. Do not care to share again how upsetting this visit was. Im trying to overlook it and trying to have trust in ths DR all over again
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9987078e-01 1.2921308e-04]
#
# Text: I have no worries about the radiation treatment I completed last month both Dr. Poppe and Dr. Chen are very thorough.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988866e-01 1.1128626e-04]
#
# Text: My wife and I both left the center feeling that we had just received the most excellent care and information.  Thanks so much for everything.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9987304e-01 1.2689678e-04]
#
# Text: It was not clear as to whether the antibiotic was to be started the day of the surgery or the day after. He seemed to be in a rush whe stopped in after the surgery. He gave us very basic fu instructions but the instruction sheet was very through and helpful.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9985588e-01 1.4405216e-04]
#
# Text: Only saw the Nurse for allergy injection.  I had no reaction so there was no need to see a doctor this time.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9987733e-01 1.2267704e-04]
#
# Text: If there was a level higher than 5 I would mark it. Dr. Tyser has provided me with excellent care.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9987769e-01 1.2232125e-04]
#
# Text: I like Dr. Briley so much that I made a special trip from Salt Lake City just to use her services.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9986959e-01 1.3037161e-04]
#
# Text: I have always received wonderful care from Dr. Ward and his staff
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989319e-01 1.0675219e-04]
#
# Text: I dont like being asked to feel out a survey each time I come in.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988592e-01 1.1409932e-04]
#
# Text: Dr had to cut our appointment short due to an emergent situation with another patient. It seemed to be an overall busy clinic day and dr was a little distracted because of this. We had a routine visit so it wasnt a big deal. However our daughter almost ended up getting an extra immunization that she didnt need but we ended up waiting for the following week to have it done which prevented her from receiving that extra immunization
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [0.6859735  0.31402642]
#
# Text: My care provider is very thorough and knowledgeable.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989748e-01 1.0248918e-04]
#
# Text: I totally trust my Doctor who has my best interests at heart understanding my individual limitations.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989676e-01 1.0325817e-04]
#
# Text: I trust Dr Morrell he always listens answers my questions  he always makes me feel that he cares about me and my health.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989498e-01 1.0495871e-04]
#
# Text: Chris is awesome on my last visit he sat down with me and went over MyChart and made sure I understood how to read it. I can actually understand what Im reading now instead of just seeing numbers on a chart.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99890447e-01 1.09501474e-04]
#
# Text: Dr. Kendall is one of my favorite doctors that I have ever had.   Im very picky about doctors and dont like that many of them.   Dr. Kendall gives me what I need from a doctor.  Excellent treatment and kind and concerned consultation with good information.  He appears to be interested in solving my medical problems.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.998951e-01 1.049341e-04]
#
# Text: Dr. Zorn listened carefully to some concerns I have about PD and meds.  She also carefully noted my condition and how I was doing.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99885201e-01 1.14737355e-04]
#
# Text: Everything was excellent
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989164e-01 1.0836613e-04]
#
# Text: Excellent provider.  Will not go anywhere else for my eye care
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99898076e-01 1.01932164e-04]
#
# Text: We see the PA Tyler Nelson just because he seems to care more about getting a solution than getting us out of the office.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9

# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9986231e-01 1.3770531e-04]
#
# Text: I want to state this again as I mentioned on the previous page I think its a gross misuse of time to continuously ask the same questons at each annual visit.  The electronic medical chart or any chart for that matter seems unnecessary as that information should already be in my chart.  Perhaps using since your last visit have you had any changes in your health...  Or referring to the previous visits notes may speed the process.  Asking me when I had my teeth removed over 20 years ago seems irrelavent since it should be in my records plus you run the risk that I could be giving you inaccurate data since it was so long ago.  Maybe Im missing something about what is really being asked by the nurse but personally I think its inefficient and could lead to incorrect data collection.  The farther away from the actual surgery or procedure youre wanting to know about the less accurate your data will be.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9981731e-01 1.8267237e-04]
#
# Text: no problems
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988353e-01 1.1646291e-04]
#
# Text: good
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99893308e-01 1.06685424e-04]
#
# Text: i guess im never sure that what i go in for is actually solved until i am able to see the results from the prescriptions. he was perfectly great through my appointment so i do hope that the results are as equally good. the appointment really was perfectly fine overall.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988496e-01 1.1507396e-04]
#
# Text: Dr. Bowen always takes whatever time is needed to listen to my concerns. He makes sure I completely understand what treatments are needed. He is very professional friendly caring and thorough.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99894738e-01 1.05287916e-04]
#
# Text: At the beginning I really Like Dr. Pham.  She seems to be frustrated with me.  I have other Doctors help me and are patient with me.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988854e-01 1.1145735e-04]
#
# Text: My care providers are the best that i have ever had. Would never change a thing.  My care providers just have to look at me and  they know what is wrong Johanna Greenburg and  Dr Salari  are the best i just love them both.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99878049e-01 1.21919715e-04]
#
# Text: Having a care provider that is able and willing to partner with me is of great concern to me. My care provider is able to be part of a partnership that is focused on my care and increased understanding of my medical needs.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989069e-01 1.0931369e-04]
#
# Text: a great experience.  Would see this ortho provider again if needed.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99891281e-01 1.08746244e-04]
#
# Text: all very good
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989331e-01 1.0667648e-04]
#
# Text: Follow care was not discussed so I was not pleased with that.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99893069e-01 1.06937005e-04]
#
# Text: Dr. Allred seems competent and paid attention.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99896526e-01 1.03454004e-04]
#
# Text: Dr Kelly Murnin is excellent.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99894977e-01 1.05031606e-04]
#
# Text: Dr. Kolb was just terrific relaxed attentive caring thorough in history and physical extremely good at eliciting concerns and answering questions involved the patient and family in decision making about further evaluation and management. Its hard to imagine how his care could have been any better
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99888182e-01 1.11781665e-04]
#
# Text: My hesitation on recommending has nothing to do with the provider it would have to do with the ability to get into and get appointment in a timely manner.
# True Label: 1.0
# Predicted Label: 0
# Probabilities: [9.9980336e-01 1.9663529e-04]
#
# Text: Dr Norton was wonderful and very thorough. She further explained the time delay and was very apologetic. I was not in a rush so it was totally fine.  She was wonderful
# True Label: 1.0
# Predicted Label: 0
# Probabilities: [9.9983203e-01 1.6792359e-04]
#
# Text: Felt rushed
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9987900e-01 1.2095951e-04]
#
# Text: Both Betty King and Dr. Hull were great
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99892116e-01 1.07876185e-04]
#
# Text: Dr. Kubiak took time to answer all my questions which I discovered later are answered in the notebook My Guide to Joint Replacement.  He could have just said We have a notebook that will answer all you questions but he took the time to answer.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9986494e-01 1.3510519e-04]
#
# Text: Dr. Pippitt is friendly funny kind smart and doesnt make me feel stupid for asking questions.  She is always thinking about all options and does a great job laying them out for me in a way that helps me understand what is going on and what decisions Ill need to make.  I enjoy my visits to the clinic because Dr. Pippitt is so awesome
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9987817e-01 1.2176426e-04]
#
# Text: Dr. Shprecher was very patient thorough and listened intently to anything I asked or expressed.  Very impressive
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988568e-01 1.1428955e-04]
#
# Text: Dr. Penrod did not listen to my problem at all or discuss it with me.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988377e-01 1.1624955e-04]
#
# Text: really good in comunication and careing
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988723e-01 1.1274662e-04]
#
# Text: I am so happy with my providers as well as the U of U
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99882698e-01 1.17271506e-04]
#
# Text: Dr Stoneberger is a very good MD. I had no problem with his care concerns or recommendations for treatment to resolve my immediate problem.  But If I cant get an appointment back with him for follow up in his recommended time LIKE THE NEXT DAY. WHAT IS THE POINT IN HIM SEEING ME IN THE FIRST PLACE OR TELLING ME TO COME BACK FOR ADDITIONAL TREATMENT THE NEXT DAY WHEN I CANT GET AN APPOINTMENT WITH HIM
# True Label: 1.0
# Predicted Label: 0
# Probabilities: [9.9972957e-01 2.7046938e-04]
#
# Text: Without a doubt I will recommend this staff and Dr. Myers to any of my friends and family
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99880791e-01 1.19208846e-04]
#
# Text: I felt no rush from the doctor the nurse or the residence.  They have a very good sense of empathy.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989688e-01 1.0315336e-04]
#
# Text: Explained things well Didnt feel rushed.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99883175e-01 1.16859264e-04]
#
# Text: I absolutely adore Dr. Shami  Renee
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99891758e-01 1.08251894e-04]
#
# Text: I would highly recommend Dr. Robert Hood to anyone in need of back surgery.  He spent a lot of time with my husband and me discussing what needed to be done to correct the problem with my vertebrae which were out of alignment.  The surgery and recovery went very well and I no longer suffer from painful sciatica.  Im very grateful
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99884963e-01 1.14966686e-04]
#
# Text: When I go to other U of U clinics I am given a print out with diagnosis explanations and instructions followup etc.  I like this very much.  When a great deal of information is given it is hard to remember all of it  It would be wonderful if the Moran Eye Center had a similar print out at the end of the appointment including what to do if an emergency.  Also the technician I saw in the beginning told me the chart stated I had mild beginning of cateracs sp forming.  I have never been told this by any of the three doctors I have seen.  It would be nice to have information about this.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9982721e-01 1.7287956e-04]
#
# Text: new doctor for meliked her very much.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99894977e-01 1.04980834e-04]
#
# Text: Great
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.998870e-01 1.129444e-04]
#
# Text: very good
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989808e-01 1.0188241e-04]
#
# Text: good
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99893308e-01 1.06685424e-04]
#
# Text: great doctor just had to wait forever
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [8.7082369e-04 9.9912924e-01]
#
# Text: please remind house staff the fellow that one can hear a lot through the wooden exam doors...
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988282e-01 1.1714287e-04]
#
# Text: Dr Dhillon would not help to prescribe percocet to take during the day for my back pain. She suggested I go to the ER if the pain was that bad.  I came to her to avoid the cost of the ER.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9986839e-01 1.3163392e-04]
#
# Text: The whole experience was wonderful
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988854e-01 1.1143504e-04]
#
# Text: Letting Dr. Tilly leave the University is a huge mistake  those who let this happen should be questioned...
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9983954e-01 1.6038361e-04]
#
# Text: With Drs Pittman and Junkins I wish there was a higher value than Very Good.   These doctors are very caring very attentive and seem genuinely concerned with your wellbeing.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989474e-01 1.0522789e-04]
#
# Text: The resident was very helpful and informative
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989820e-01 1.0178676e-04]
#
# Text: I would not see any one else but dr seibert she is a fine doctor cares about her work
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988592e-01 1.1407647e-04]
#
# Text: Signed up for my chart was able to get the information from that. Didnt understand some of the information. Not sure if I should make an appointment to go over it.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9

# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99893069e-01 1.06963525e-04]
#
# Text: My mother is 90 years old and I felt like the doctor was rude and condescending. She cant hear well and he was impatient. I take my mother to most of her appointments at the Centerville Clinic and I have loved all of the other doctors working there. This guy was a creep.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988759e-01 1.1245082e-04]
#
# Text: My son had a good experience with Bryan Franco. He showed he could relate with my son at many levels showed he cared for his interests asked questions about his school sports friends. Took his time to answer any questions or concerns we both had. This has been our first appointment with Bryan and I and my son were satisfied with the way we were treated. I would definitely recommend Bryan with friends and family.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99884725e-01 1.15290335e-04]
#
# Text: We have many specialists for our daughters care. Dr. Meier is by far one of our favorites. He is the perfect combination of friendly caring bedside manner along with unparalleled expertise. He is thoughtful intentional and always listens to our ideas and concerns. He realizes that we are very well informed parents and adapts our conversations to an appropriate level. Ive already recommended him to others as we feel like we won the ENT lottery
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99884963e-01 1.14981274e-04]
#
# Text: all around excellent staff and service of care.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989474e-01 1.0523230e-04]
#
# Text: I have gone to Michelle for years she always make me feel that she is not rushed and listes to me.  She explains what is going on
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9985611e-01 1.4384558e-04]
#
# Text: Love her
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988174e-01 1.1821247e-04]
#
# Text: It was not explained as to exactly why I need to see a Retina Specialist.  To be told a second opinion is needed to ensure what Dr. Vincent has seen does not help me.  It leaves me to worry about what the issue may or may not be.  Detailed info would be helpful now I am hanging out there a bit and a bit worried.  I still do not have an appointment set up...Im on a bump list...I do not know what this means and I travel.  Perhaps a definitive appointment and knowing what I am to be seen for would be helpful.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9982196e-01 1.7804485e-04]
#
# Text: Dr. GoldmanLuthy was wonderful  interacted with my child very effectively.  She spend sufficient time with us  I am very pleased with her as a provider.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988782e-01 1.1211472e-04]
#
# Text: I have had very good service throughout my Moran experiences.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.99892354e-01 1.07646214e-04]
#
# Text: I had waited 2 years for an ankle replacement.  The experience was nothing but great all through the process.  From Lindsay setting up surgery and appointment to Drs visits to post surgery in the hospital it was all very positive.  I have a great deal of confidence my results will be great
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9983573e-01 1.6424293e-04]
#
# Text: Dr. Kiraly is the BEST  She listens  supports all my concerns  Her one on one with me is GREAT
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.998852e-01 1.147297e-04]
#
# Text: Julie Crandall and Dr. Crandall provide excellent care and are always friendly and informative.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989545e-01 1.0453720e-04]
#
# Text: Never actually have seen the doctor to which I schedule to see. Always have to see his midwife or nurse practitioner even though I would prefer to see the actual doctor
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9987507e-01 1.2487965e-04]
#
# Text: I love Dr. Moshirfar.  He has been very good to me very caring kind and considerate.  I think he is an EXCEPTIONAL DOCTOR.  You dont find one like everyday.  Very happy with him.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989510e-01 1.0495011e-04]
#
# Text: Dr. Shprecher is very professional  absolutely amazing
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989617e-01 1.0384471e-04]
#
# Text: very good
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9989808e-01 1.0188241e-04]
#
# Text: Wendy is very kind caring and sweet.  You can tell she genuinely cares about you and she takes the time to address your questions and explain your medicalhealth issues.
# True Label: 0.0
# Predicted Label: 0
# Probabilities: [9.9988723e-01 1.1280588e-04]

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
from google.colab import output
output.disable_custom_widget_manager()
